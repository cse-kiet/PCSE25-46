# %%
# !pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in c:\users\priyv\anaconda3\lib\site-packages (0.2.14)

# %% [markdown]
# # Audio recording samp1

# %%
import pyaudio
import wave
CHUNK = 2048 
FORMAT = pyaudio.paInt16 #paInt8
CHANNELS = 2 
RATE = 44100 #sample rate
RECORD_SECONDS = 10
WAVE_OUTPUT_FILENAME = "given_file.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK) #buffer

print("* recording")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data) # 2 bytes(16 bits) per channel

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# * recording
# * done recording

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\priyv\cse

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 5EFD-0370
#
#  Directory of C:\Users\priyv\cse
#
# 18-12-2024  14:37    <DIR>          .
# 18-12-2024  14:07    <DIR>          ..
# 18-12-2024  03:14    <DIR>          .ipynb_checkpoints
# 18-12-2024  14:37         2,434,679 audio_prep_extract.ipynb
# 29-08-2024  10:12    <DIR>          cse1
# 29-08-2024  10:18                39 devops
# 18-12-2024  03:00        11,229,288 emotion_recognition_ann_model.h5
# 18-12-2024  03:31        10,144,488 emotion_recognition_model.h5
# 18-12-2024  03:45        10,142,153 emotion_recognition_model.keras
# 29-08-2024  10:16    <DIR>          file1
# 29-08-2024  10:16    <DIR>          file10
# 29-08-2024  10:16    <DIR>          file2
# 29-08-2024  10:16    <DIR>          file3
# 29-08-2024  10:16    <DIR>          file4
# 29-08-2024  10:16    <DIR>          file5
# 29-08-2024  10:16    <DIR>          file6
# 29-08-2024  10:16    <DIR>          file7
# 29-08-2024  10:16    <DIR>          file8
# 29-08-2024  10:16    <DIR>          file9
# 18-12-2024  03:00               313 label_encoder.pkl
# 29-08-2024  10:24                39 mlops
# 29-08-2024  10:46                33 new.txt
# 29-08-2024  10:44                61 newfile.txt
# 18-12-2024  14:58         1,761,324 output.wav
# 18-12-2024  14:36           752,954 ravdess_mfcc_features.csv
# 18-12-2024  03:00             5,718 scaler.pkl
# 07-10-2024  13:54    <DIR>          speech-emotion-recognition-ravdess-data
#               12 File(s)     36,471,089 bytes
#               15 Dir(s)  75,583,111,168 bytes free

# %%
import matplotlib.pyplot as plt

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\priyv\anaconda3\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (0.59.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\priyv\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in c:\users\priyv\anaconda3\lib\site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\priyv\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\priyv\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\priyv\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\priyv\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\priyv\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\priyv\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\priyv\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\priyv\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\priyv\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\priyv\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)

# %%
import librosa
import librosa.display

# %%
import IPython.display as ipd

# %% [markdown]
# ## Waveform of the given audio input

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd

fname = 'given_file.wav'

data, samp_rate = librosa.load(fname)

plt.figure(figsize=(10, 4))  
librosa.display.waveshow(data, sr=samp_rate)
plt.title('Waveform of Audio Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

ipd.Audio(fname)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## making panda series

# %%
import pandas as pd

# %%
pd.Series(data)
# Out:
# 0        -3.085730e-06
# 1        -9.936893e-06
# 2        -2.900808e-06
# 3         9.140126e-08
# 4         8.371262e-07
#               ...
# 220155   -1.728308e-03
# 220156   -1.373756e-03
# 220157   -8.192552e-04
# 220158   -1.501305e-04
# 220159   -2.972534e-04
# Length: 220160, dtype: float32

# %% [markdown]
# # Features Extractor

# %%
mfccs = librosa.feature.mfcc(y=data, sr=samp_rate, n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 431)

# %%
mfccs
# Out:
# array([[-7.7043390e+02, -7.7043390e+02, -7.7043390e+02, ...,
#         -7.5729504e+02, -7.4881018e+02, -7.3857465e+02],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          1.8127630e+01,  2.9719482e+01,  4.2354309e+01],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          1.6868172e+01,  2.7295574e+01,  3.5292160e+01],
#        ...,
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          1.0957845e+00,  8.6069441e-01,  2.7330616e-01],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          9.1614306e-01,  9.9844569e-01,  2.0473826e-01],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          3.3780283e-01,  7.8289616e-01,  5.0973475e-02]], dtype=float32)

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name) 
    mfccs_features = librosa.feature.mfcc(y=data, sr=samp_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %% [markdown]
# # load dataset and data preprocessing

# %%
import os
import librosa
import pandas as pd
import numpy as np

# Emotion mapping based on RAVDESS file naming convention
EMOTIONS = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

def parse_ravdess_filename(file_name):
    """
    Parse the RAVDESS filename to extract the emotion label and other metadata.
    """
    parts = file_name.split('-')
    emotion_code = parts[2] 
    emotion = EMOTIONS.get(emotion_code, "unknown")
    return emotion

def extract_audio_features(file_path, n_mfcc=40):
    """
    Extract only MFCC features from a file.
    """
    try:
        y, sr = librosa.load(file_path, sr=None)
        duration = librosa.get_duration(y=y, sr=sr)
        
        
        mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc).T, axis=0)
        
        return {
            "duration": duration,
            "sample_rate": sr,
            **{f"mfcc_{i+1}": mfcc for i, mfcc in enumerate(mfccs)}
        }
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

def ravdess_to_csv(dataset_path, output_csv_path):
    """
    Process RAVDESS audio files from a folder structure like Actor_01, Actor_02, ..., Actor_24
    and save metadata and features (only MFCC) to a CSV file.
    """
    data = []

    
    for actor_folder in os.listdir(dataset_path):
        actor_path = os.path.join(dataset_path, actor_folder)
        if os.path.isdir(actor_path):  
            for file in os.listdir(actor_path):
                if file.endswith(".wav"):
                    file_path = os.path.join(actor_path, file)
                    emotion_label = parse_ravdess_filename(file)

                    # Extract MFCC features
                    features = extract_audio_features(file_path)
                    if features:
                        features["file_path"] = file_path
                        features["actor"] = actor_folder  
                        features["label"] = emotion_label
                        data.append(features)

   
    df = pd.DataFrame(data)
    df.to_csv(output_csv_path, index=False)
    print(f"CSV file saved to {output_csv_path}")


dataset_path = "speech-emotion-recognition-ravdess-data"  
output_csv_path = "ravdess_mfcc_features.csv"
ravdess_to_csv(dataset_path, output_csv_path)
# Out:
# CSV file saved to ravdess_mfcc_features.csv

# %%
import os
print(os.path.exists(output_csv_path))
# Out:
# True

# %%
test_file = "speech-emotion-recognition-ravdess-data/Actor_01/03-01-01-01-02-01-01.wav"
features = extract_audio_features(test_file)
print(features)
# Out:
# {'duration': 3.2699375, 'sample_rate': 16000, 'mfcc_1': -677.8081, 'mfcc_2': 51.402702, 'mfcc_3': -0.009545798, 'mfcc_4': 14.301585, 'mfcc_5': 0.7671622, 'mfcc_6': -0.23838186, 'mfcc_7': -6.169594, 'mfcc_8': -10.741854, 'mfcc_9': -7.6211886, 'mfcc_10': 1.282321, 'mfcc_11': -3.8150868, 'mfcc_12': 1.9573514, 'mfcc_13': -5.7387285, 'mfcc_14': 0.3985472, 'mfcc_15': -2.4818628, 'mfcc_16': -5.3536325, 'mfcc_17': -1.3868858, 'mfcc_18': 0.85493225, 'mfcc_19': -5.603166, 'mfcc_20': -2.0104146, 'mfcc_21': -2.2021217, 'mfcc_22': -4.327673, 'mfcc_23': -0.26211378, 'mfcc_24': -2.7748287, 'mfcc_25': -2.8519413, 'mfcc_26': -1.027859, 'mfcc_27': -1.7407987, 'mfcc_28': -0.80484164, 'mfcc_29': -3.126437, 'mfcc_30': -2.0625024, 'mfcc_31': -2.6007326, 'mfcc_32': -2.66617, 'mfcc_33': -2.000873, 'mfcc_34': -1.4351019, 'mfcc_35': -4.338004, 'mfcc_36': -2.7257943, 'mfcc_37': -3.0296626, 'mfcc_38': -1.5409077, 'mfcc_39': -2.3167748, 'mfcc_40': -2.4746187}

# %%
import pandas as pd
df = pd.read_csv("ravdess_mfcc_features.csv")
df.head()
# Out:
#    duration  sample_rate     mfcc_1     mfcc_2    mfcc_3     mfcc_4    mfcc_5  \
# 0  3.303313        16000 -693.49700  50.064392  0.571451  14.329966  3.336370
# 1  3.336688        16000 -683.34680  48.889260 -1.683444  19.183002  1.969590
# 2  3.269938        16000 -677.80810  51.402702 -0.009546  14.301585  0.767162
# 3  3.169812        16000 -674.01917  50.680557  1.878226  14.295362  3.069178
# 4  3.536875        16000 -709.05680  55.734306  2.668310  16.362572  3.344781
#
#      mfcc_6    mfcc_7     mfcc_8  ...   mfcc_34   mfcc_35   mfcc_36   mfcc_37  \
# 0 -2.540719 -4.057909 -10.711999  ... -0.554154 -3.964599 -2.134852 -3.945771
# 1 -0.799272 -4.795028 -12.342567  ... -1.865460 -4.270066 -2.396406 -4.606637
# 2 -0.238382 -6.169594 -10.741854  ... -1.435102 -4.338004 -2.725794 -3.029663
# 3  1.584900 -7.450740 -11.413989  ... -1.310382 -3.588744 -3.792770 -3.513380
# 4 -1.124848 -5.818393  -8.999178  ... -1.536171 -3.605385 -3.623699 -4.169817
#
#     mfcc_38   mfcc_39   mfcc_40  \
# 0 -1.624579 -2.039907 -3.629108
# 1 -1.184742 -2.140252 -2.958484
# 2 -1.540908 -2.316775 -2.474619
# 3 -1.512921 -2.195736 -2.678607
# 4 -2.332985 -1.299511 -1.498474
#
#                                            file_path     actor    label
# 0  speech-emotion-recognition-ravdess-data\Actor_...  Actor_01  neutral
# 1  speech-emotion-recognition-ravdess-data\Actor_...  Actor_01  neutral
# 2  speech-emotion-recognition-ravdess-data\Actor_...  Actor_01  neutral
# 3  speech-emotion-recognition-ravdess-data\Actor_...  Actor_01  neutral
# 4  speech-emotion-recognition-ravdess-data\Actor_...  Actor_01     calm
#
# [5 rows x 45 columns]

# %% [markdown]
# # Train ANN Using CSV Data

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler 
from tensorflow.keras.utils import to_categorical  
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import librosa

# Load csv
csv_file = "ravdess_mfcc_features.csv" 
data = pd.read_csv(csv_file)

# Features and Labels
X = data.drop(columns=["file_path", "actor", "label"])
y = data["label"]

# Encode Labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_one_hot = to_categorical(y_encoded)

# Scale Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_one_hot, test_size=0.2, random_state=42)

# Build ANN 
model = Sequential([
    Input(shape=(X_train.shape[1],)), 
    Dense(800, activation="relu"),
    Dropout(0.5),
    Dense(500, activation="relu"),
    Dropout(0.5),
    Dense(800, activation="relu"),
    Dropout(0.5),
    Dense(y_one_hot.shape[1], activation="softmax")
])

# Compile the Model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1)
early_stopper = EarlyStopping(monitor="val_accuracy", patience=20, restore_best_weights=True)

# Train the Model
history = model.fit(
    X_train, y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[lr_scheduler, early_stopper]
)

# Evaluate the Model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Save the Model in the New Format
model.save("emotion_recognition_model.keras")  
print("Model saved as emotion_recognition_model.keras")
# Out:
# Epoch 1/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1689 - loss: 2.0854 - val_accuracy: 0.3021 - val_loss: 1.7592 - learning_rate: 0.0010
# Epoch 2/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3012 - loss: 1.8044 - val_accuracy: 0.3611 - val_loss: 1.5520 - learning_rate: 0.0010
# Epoch 3/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4100 - loss: 1.5317 - val_accuracy: 0.4653 - val_loss: 1.3717 - learning_rate: 0.0010
# Epoch 4/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4595 - loss: 1.4027 - val_accuracy: 0.4965 - val_loss: 1.2890 - learning_rate: 0.0010
# Epoch 5/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5248 - loss: 1.3017 - val_accuracy: 0.5312 - val_loss: 1.2046 - learning_rate: 0.0010
# Epoch 6/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5471 - loss: 1.2416 - val_accuracy: 0.5278 - val_loss: 1.2094 - learning_rate: 0.0010
# Epoch 7/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5698 - loss: 1.1850 - val_accuracy: 0.5382 - val_loss: 1.1859 - learning_rate: 0.0010
# Epoch 8/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6118 - loss: 1.0087 - val_accuracy: 0.5451 - val_loss: 1.1163 - learning_rate: 0.0010
# Epoch 9/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6285 - loss: 0.9829 - val_accuracy: 0.5694 - val_loss: 1.1058 - learning_rate: 0.0010
# Epoch 10/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6295 - loss: 0.9280 - val_accuracy: 0.5764 - val_loss: 1.0778 - learning_rate: 0.0010
# Epoch 11/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6887 - loss: 0.8806 - val_accuracy: 0.6215 - val_loss: 1.0536 - learning_rate: 0.0010
# Epoch 12/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6938 - loss: 0.8200 - val_accuracy: 0.5868 - val_loss: 1.0495 - learning_rate: 0.0010
# Epoch 13/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6864 - loss: 0.8106 - val_accuracy: 0.5972 - val_loss: 1.0053 - learning_rate: 0.0010
# Epoch 14/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7235 - loss: 0.7640 - val_accuracy: 0.6181 - val_loss: 1.0212 - learning_rate: 0.0010
# Epoch 15/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7526 - loss: 0.6945 - val_accuracy: 0.6076 - val_loss: 1.0142 - learning_rate: 0.0010
# Epoch 16/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7607 - loss: 0.6655 - val_accuracy: 0.6424 - val_loss: 0.9988 - learning_rate: 0.0010
# Epoch 17/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7806 - loss: 0.6063 - val_accuracy: 0.6250 - val_loss: 1.0418 - learning_rate: 0.0010
# Epoch 18/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7900 - loss: 0.5758 - val_accuracy: 0.6528 - val_loss: 0.9746 - learning_rate: 0.0010
# Epoch 19/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7776 - loss: 0.5727 - val_accuracy: 0.6806 - val_loss: 0.9925 - learning_rate: 0.0010
# Epoch 20/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7994 - loss: 0.5466 - val_accuracy: 0.6806 - val_loss: 0.9304 - learning_rate: 0.0010
# Epoch 21/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7998 - loss: 0.5272 - val_accuracy: 0.6389 - val_loss: 0.9818 - learning_rate: 0.0010
# Epoch 22/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8124 - loss: 0.5358 - val_accuracy: 0.6771 - val_loss: 0.9429 - learning_rate: 0.0010
# Epoch 23/500
# 32/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8257 - loss: 0.4931
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8260 - loss: 0.4936 - val_accuracy: 0.6840 - val_loss: 0.9894 - learning_rate: 0.0010
# Epoch 24/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8500 - loss: 0.4333 - val_accuracy: 0.7118 - val_loss: 0.8838 - learning_rate: 5.0000e-04
# Epoch 25/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8794 - loss: 0.3686 - val_accuracy: 0.6910 - val_loss: 0.9059 - learning_rate: 5.0000e-04
# Epoch 26/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8743 - loss: 0.3488 - val_accuracy: 0.7049 - val_loss: 0.8471 - learning_rate: 5.0000e-04
# Epoch 27/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8779 - loss: 0.3378 - val_accuracy: 0.7153 - val_loss: 0.8320 - learning_rate: 5.0000e-04
# Epoch 28/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8619 - loss: 0.3935 - val_accuracy: 0.6979 - val_loss: 0.9485 - learning_rate: 5.0000e-04
# Epoch 29/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9020 - loss: 0.3040 - val_accuracy: 0.6944 - val_loss: 0.9123 - learning_rate: 5.0000e-04
# Epoch 30/500
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9076 - loss: 0.2734
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9064 - loss: 0.2761 - val_accuracy: 0.7153 - val_loss: 0.9258 - learning_rate: 5.0000e-04
# Epoch 31/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8878 - loss: 0.2901 - val_accuracy: 0.7083 - val_loss: 0.8898 - learning_rate: 2.5000e-04
# Epoch 32/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8801 - loss: 0.3162 - val_accuracy: 0.7257 - val_loss: 0.8815 - learning_rate: 2.5000e-04
# Epoch 33/500
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8958 - loss: 0.2724
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8970 - loss: 0.2709 - val_accuracy: 0.7118 - val_loss: 0.9159 - learning_rate: 2.5000e-04
# Epoch 34/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.2250 - val_accuracy: 0.7188 - val_loss: 0.9252 - learning_rate: 1.2500e-04
# Epoch 35/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9146 - loss: 0.2351 - val_accuracy: 0.7153 - val_loss: 0.9064 - learning_rate: 1.2500e-04
# Epoch 36/500
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9304 - loss: 0.2308
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9288 - loss: 0.2354 - val_accuracy: 0.7222 - val_loss: 0.9132 - learning_rate: 1.2500e-04
# Epoch 37/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9332 - loss: 0.2036 - val_accuracy: 0.7188 - val_loss: 0.9125 - learning_rate: 6.2500e-05
# Epoch 38/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9186 - loss: 0.2288 - val_accuracy: 0.7188 - val_loss: 0.9104 - learning_rate: 6.2500e-05
# Epoch 39/500
# 32/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9195 - loss: 0.2320
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9192 - loss: 0.2314 - val_accuracy: 0.7188 - val_loss: 0.9163 - learning_rate: 6.2500e-05
# Epoch 40/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.2157 - val_accuracy: 0.7222 - val_loss: 0.9165 - learning_rate: 3.1250e-05
# Epoch 41/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9193 - loss: 0.2409 - val_accuracy: 0.7222 - val_loss: 0.9150 - learning_rate: 3.1250e-05
# Epoch 42/500
# 18/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9323 - loss: 0.2054
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9248 - loss: 0.2207 - val_accuracy: 0.7222 - val_loss: 0.9146 - learning_rate: 3.1250e-05
# Epoch 43/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9297 - loss: 0.1992 - val_accuracy: 0.7257 - val_loss: 0.9121 - learning_rate: 1.5625e-05
# Epoch 44/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9286 - loss: 0.2023 - val_accuracy: 0.7257 - val_loss: 0.9109 - learning_rate: 1.5625e-05
# Epoch 45/500
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9405 - loss: 0.1959
# Epoch 45: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9382 - loss: 0.1991 - val_accuracy: 0.7292 - val_loss: 0.9114 - learning_rate: 1.5625e-05
# Epoch 46/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9324 - loss: 0.2261 - val_accuracy: 0.7292 - val_loss: 0.9102 - learning_rate: 7.8125e-06
# Epoch 47/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9513 - loss: 0.1657 - val_accuracy: 0.7257 - val_loss: 0.9105 - learning_rate: 7.8125e-06
# Epoch 48/500
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9466 - loss: 0.1841
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9456 - loss: 0.1849 - val_accuracy: 0.7222 - val_loss: 0.9099 - learning_rate: 7.8125e-06
# Epoch 49/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9291 - loss: 0.2082 - val_accuracy: 0.7188 - val_loss: 0.9097 - learning_rate: 3.9063e-06
# Epoch 50/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9295 - loss: 0.2218 - val_accuracy: 0.7188 - val_loss: 0.9096 - learning_rate: 3.9063e-06
# Epoch 51/500
# 27/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9243 - loss: 0.2296
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9221 - loss: 0.2325 - val_accuracy: 0.7188 - val_loss: 0.9095 - learning_rate: 3.9063e-06
# Epoch 52/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9283 - loss: 0.2112 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 1.9531e-06
# Epoch 53/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9363 - loss: 0.1968 - val_accuracy: 0.7188 - val_loss: 0.9095 - learning_rate: 1.9531e-06
# Epoch 54/500
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9176 - loss: 0.2146
# Epoch 54: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9179 - loss: 0.2141 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 1.9531e-06
# Epoch 55/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.2017 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 9.7656e-07
# Epoch 56/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9423 - loss: 0.1994 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 9.7656e-07
# Epoch 57/500
# 30/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9256 - loss: 0.2000
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9278 - loss: 0.1978 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 9.7656e-07
# Epoch 58/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9438 - loss: 0.1867 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 4.8828e-07
# Epoch 59/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9384 - loss: 0.1950 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 4.8828e-07
# Epoch 60/500
# 30/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9156 - loss: 0.2146
# Epoch 60: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9158 - loss: 0.2171 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 4.8828e-07
# Epoch 61/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9269 - loss: 0.1950 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 2.4414e-07
# Epoch 62/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9429 - loss: 0.1979 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 2.4414e-07
# Epoch 63/500
# 27/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9169 - loss: 0.2039
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9195 - loss: 0.2058 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 2.4414e-07
# Epoch 64/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9334 - loss: 0.1931 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 1.2207e-07
# Epoch 65/500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9353 - loss: 0.1866 - val_accuracy: 0.7188 - val_loss: 0.9094 - learning_rate: 1.2207e-07
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7286 - loss: 0.9982
# Test Accuracy: 72.92%
# Model saved as emotion_recognition_model.keras

# %% [markdown]
# # Predictor Function

# %%
def predict_emotion(audio_file):
    """
    Predict the emotion of the given audio file.

    Args:
        audio_file (str): Path to the audio file.

    Returns:
        str: Predicted emotion label.
    """
    # Load the saved model
    model = load_model("emotion_recognition_model.keras")  

    
    y, sr = librosa.load(audio_file, duration=2.5, offset=0.6, sr=22050)  # Load the audio
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)  # Extract MFCC features
    mfccs_mean = np.mean(mfccs.T, axis=0)  

    
    num_features = X_train.shape[1]  
    if len(mfccs_mean) < num_features:
        
        mfccs_mean = np.pad(mfccs_mean, (0, num_features - len(mfccs_mean)), mode='constant')
    elif len(mfccs_mean) > num_features:
        
        mfccs_mean = mfccs_mean[:num_features]

   
    mfccs_scaled = scaler.transform([mfccs_mean])  # Ensure it matches the scaler

   
    prediction = model.predict(mfccs_scaled)
    predicted_label = np.argmax(prediction)

    
    emotion = label_encoder.inverse_transform([predicted_label])[0]
    return emotion


audio_file = "given_file.wav" 

predicted_emotion = predict_emotion(audio_file)
print(f"The predicted emotion is: {predicted_emotion}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# The predicted emotion is: happy
# C:\Users\priyv\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Model Loss

# %%
import matplotlib.pyplot as plt

# Plot model loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

def plot_spectrogram(audio_file):
    
    # Load the audio file
    y, sr = librosa.load(audio_file, duration=2.5, offset=0.6, sr=22050)  # Matches training parameters

    # Short-Time Fourier Transform (STFT)
    D = librosa.stft(y)

    # Convert to decibels (log scale) for visualization
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)

    # Plot the Spectrogram
    fig, ax = plt.subplots(figsize=(10, 5))
    img = librosa.display.specshow(S_db, x_axis="time", y_axis="log", sr=sr, ax=ax)
    
    ax.set_title("Spectrogram of Audio", fontsize=20)
    fig.colorbar(img, ax=ax, format="%0.2f")  
    plt.show()


plot_spectrogram("given_file.wav")
